# %% [markdown]
# # AI - GLOBAL VARIABLES LOVERS

# %% [markdown]
# # Importing libraries

# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # LOADING DATASET

# %%
df = pd.read_csv("final_train.csv")

# %%
df
# Out:
#        Unnamed: 0            Activity  angle(X,gravityMean)  \
# 0               0            STANDING             -1.574191
# 1               1    WALKING_UPSTAIRS             -1.568669
# 2               2              LAYING             -1.548333
# 3               3             WALKING             -1.574094
# 4               4              LAYING             -1.548333
# ...           ...                 ...                   ...
# 11081       11081    WALKING_UPSTAIRS             -1.568669
# 11082       11082              LAYING             -1.550288
# 11083       11083    WALKING_UPSTAIRS             -1.569815
# 11084       11084  WALKING_DOWNSTAIRS             -1.574768
# 11085       11085             WALKING             -1.573186
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0                 -0.805700             -2.453831
# 1                 -0.612620             -2.488338
# 2                 -0.139628             -2.380889
# ...

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Activity',
#  'angle(X,gravityMean)',
#  'angle(Y,gravityMean)',
#  'angle(Z,gravityMean)',
#  'angle(tBodyAccJerkMean),gravityMean)',
#  'angle(tBodyAccMean,gravity)',
#  'angle(tBodyGyroJerkMean,gravityMean)',
#  'angle(tBodyGyroMean,gravityMean)',
#  'energy-mean()',
#  'fBodyAcc-bandsEnergy()-1,16',
#  'fBodyAcc-bandsEnergy()-1,16.1',
#  'fBodyAcc-bandsEnergy()-1,16.2',
#  'fBodyAcc-bandsEnergy()-1,24',
#  'fBodyAcc-bandsEnergy()-1,24.1',
#  'fBodyAcc-bandsEnergy()-1,24.2',
#  'fBodyAcc-bandsEnergy()-1,8',
#  'fBodyAcc-bandsEnergy()-1,8.1',
#  'fBodyAcc-bandsEnergy()-1,8.2',
#  'fBodyAcc-bandsEnergy()-17,24',
#  'fBodyAcc-bandsEnergy()-17,24.1',
#  'fBodyAcc-bandsEnergy()-17,24.2',
#  'fBodyAcc-bandsEnergy()-17,32',
#  'fBodyAcc-bandsEnergy()-17,32.1',
#  'fBodyAcc-bandsEnergy()-17,32.2',
#  'fBodyAcc-bandsEnergy()-25,32',
#  'fBodyAcc-bandsEnergy()-25,32.1',
#  'fBodyAcc-bandsEnergy()-25,32.2',
#  'fBodyAcc-bandsEnergy()-25,48',
# ...

# %% [markdown]
# # CLEANING DATASET

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.head()
# Out:
#            Activity  angle(X,gravityMean)  angle(Y,gravityMean)  \
# 0          STANDING             -1.574191             -0.805700
# 1  WALKING_UPSTAIRS             -1.568669             -0.612620
# 2            LAYING             -1.548333             -0.139628
# 3           WALKING             -1.574094             -0.793443
# 4            LAYING             -1.548333             -0.139628
#
#    angle(Z,gravityMean)  angle(tBodyAccJerkMean),gravityMean)  \
# 0             -2.453831                             -1.861714
# 1             -2.488338                             -1.751117
# 2             -2.380889                             -1.915239
# 3             -2.449959                             -1.842741
# 4             -2.380889                                   NaN
#
#    angle(tBodyAccMean,gravity)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                     0.115517                             -2.023369
# ...

# %%
df.dropna(inplace = True)

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index          Activity  angle(X,gravityMean)  angle(Y,gravityMean)  \
# 0      0          STANDING             -1.574191             -0.805700
# 1      1  WALKING_UPSTAIRS             -1.568669             -0.612620
# 2      2            LAYING             -1.548333             -0.139628
# 3      3           WALKING             -1.574094             -0.793443
# 4      5           SITTING             -1.575809             -0.640703
#
#    angle(Z,gravityMean)  angle(tBodyAccJerkMean),gravityMean)  \
# 0             -2.453831                             -1.861714
# 1             -2.488338                             -1.751117
# 2             -2.380889                             -1.915239
# 3             -2.449959                             -1.842741
# 4             -2.460251                             -1.849850
#
#    angle(tBodyAccMean,gravity)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                     0.115517                             -2.023369
# ...

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.head()
# Out:
#            Activity  angle(X,gravityMean)  angle(Y,gravityMean)  \
# 0          STANDING             -1.574191             -0.805700
# 1  WALKING_UPSTAIRS             -1.568669             -0.612620
# 2            LAYING             -1.548333             -0.139628
# 3           WALKING             -1.574094             -0.793443
# 4           SITTING             -1.575809             -0.640703
#
#    angle(Z,gravityMean)  angle(tBodyAccJerkMean),gravityMean)  \
# 0             -2.453831                             -1.861714
# 1             -2.488338                             -1.751117
# 2             -2.380889                             -1.915239
# 3             -2.449959                             -1.842741
# 4             -2.460251                             -1.849850
#
#    angle(tBodyAccMean,gravity)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                     0.115517                             -2.023369
# ...

# %%
df.Activity[df.Activity == 'STANDING'] = 0
df.Activity[df.Activity == 'WALKING_UPSTAIRS'] = 1
df.Activity[df.Activity == 'LAYING'] = 2
df.Activity[df.Activity == 'SITTING'] = 3
df.Activity[df.Activity == 'WALKING'] = 4
df.Activity[df.Activity == 'WALKING_DOWNSTAIRS'] = 5
# Out:
# <ipython-input-13-2d9e1ecdba1d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Activity[df.Activity == 'STANDING'] = 0
# <ipython-input-13-2d9e1ecdba1d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Activity[df.Activity == 'WALKING_UPSTAIRS'] = 1
# <ipython-input-13-2d9e1ecdba1d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Activity[df.Activity == 'LAYING'] = 2
# ...

# %%
df.head()
# Out:
#   Activity  angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0        0             -1.574191             -0.805700             -2.453831
# 1        1             -1.568669             -0.612620             -2.488338
# 2        2             -1.548333             -0.139628             -2.380889
# 3        4             -1.574094             -0.793443             -2.449959
# 4        3             -1.575809             -0.640703             -2.460251
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyAccMean,gravity)  \
# 0                             -1.861714                     0.115517
# 1                             -1.751117                     0.218134
# 2                             -1.915239                     0.067613
# 3                             -1.842741                    -0.195625
# 4                             -1.849850                     0.174633
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# ...

# %%
df.tail()
# Out:
#      Activity  angle(X,gravityMean)  angle(Y,gravityMean)  \
# 9619        5             -1.575492             -0.614487
# 9620        1             -1.568669             -0.612620
# 9621        2             -1.550288             -0.231565
# 9622        1             -1.569815             -0.794940
# 9623        4             -1.573186             -0.584008
#
#       angle(Z,gravityMean)  angle(tBodyAccJerkMean),gravityMean)  \
# 9619             -2.452436                             -1.732651
# 9620             -2.488338                             -1.751117
# 9621             -2.376561                             -1.868524
# 9622             -2.482325                             -1.784151
# 9623             -2.469062                             -1.770029
#
#       angle(tBodyAccMean,gravity)  angle(tBodyGyroJerkMean,gravityMean)  \
# 9619                    -0.418138                              1.768320
# 9620                     0.218134                              0.280294
# ...

# %% [markdown]
# # MODEL

# %%
from keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

# %%
y=df.Activity
X=df.drop('Activity',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9624 entries, 0 to 9623
# Columns: 572 entries, Activity to void()
# dtypes: float64(570), int64(1), object(1)
# memory usage: 42.0+ MB

# %%
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.7

train = df[msk]
test = df[~msk]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)

# %%
from keras.callbacks import EarlyStopping
stop_early = EarlyStopping(monitor='accuracy', patience=3)

# %%
model = Sequential([
   
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(256, activation="relu"),
    Dense(128, activation="relu"),
    Dense(6, activation="softmax")

])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
X_train=np.asarray(X_train).astype(np.int)

y_train=np.asarray(y_train).astype(np.int)

# %%
classifier = model.fit(X_train,
                       y_train,
                       epochs=100,
                       batch_size=128,
                       validation_split=0.2,
                       callbacks=[stop_early])
# Out:
# Epoch 1/100
# 49/49 [==============================] - 2s 28ms/step - loss: 2.0357 - accuracy: 0.3313 - val_loss: 0.7373 - val_accuracy: 0.6591
# Epoch 2/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.7463 - accuracy: 0.6613 - val_loss: 0.6621 - val_accuracy: 0.6766
# Epoch 3/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5215 - accuracy: 0.7861 - val_loss: 0.3291 - val_accuracy: 0.8747
# Epoch 4/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.3460 - accuracy: 0.8617 - val_loss: 0.2613 - val_accuracy: 0.9000
# Epoch 5/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.3311 - accuracy: 0.8654 - val_loss: 0.3019 - val_accuracy: 0.8377
# Epoch 6/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.2949 - accuracy: 0.8696 - val_loss: 0.3540 - val_accuracy: 0.8357
# Epoch 7/100
# ...

# %% [markdown]
# # TEST LOSS & TEST ACCURACY - LET'S PLOT IT

# %%
print('\nAccuracy on the test data:')
plt.plot(classifier.history['val_accuracy'])
# Out:
# Accuracy on the test data:

# %%
print('\nLoss on the test data:')
plt.plot(classifier.history['val_loss'])
# Out:
# Loss on the test data:

# %%
model.save(r'C:\Users\karol\Documents\KOZMINSKI\2 rok\BHL hackathon.h5')

# %%
keras.models.save_model(model=model, filepath=r'C:\Users\karol\Documents\KOZMINSKI\2 rok\BHL hackathon\model.h5', save_format='h5')
